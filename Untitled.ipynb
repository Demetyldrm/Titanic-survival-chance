# %%
import pandas as pd
df = pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import matplotlib.pyplot as plt
# Assuming you have a DataFrame named 'df' with columns 'Age' and 'Survived'

# Drop rows with missing age values
df_cleaned = df.dropna(subset=['Age'])

# Group data by Age and calculate the survival rate
age_survival_rate = df_cleaned.groupby('Age')['Survived'].mean()

# Create the chart
plt.figure(figsize=(10, 6))
plt.plot(age_survival_rate.index, age_survival_rate.values, marker='o', linestyle='-', color='b')
plt.xlabel('Age')
plt.ylabel('Survival Rate')
plt.title('Survival Rate by Age')
plt.grid(True)
plt.show()

# %%
# Assuming you have a DataFrame named 'df' with columns 'Pclass' and 'Survived'

# Group data by Pclass and calculate the survival rate
pclass_survival_rate = df.groupby('Pclass')['Survived'].mean()

# Create the chart
plt.figure(figsize=(6, 4))
plt.bar(pclass_survival_rate.index, pclass_survival_rate.values, color='b')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.title('Survival Rate by Passenger Class')
plt.grid(True)
plt.show()

# %%
# Assuming you have a DataFrame named 'df' with columns 'Age' and 'Survived'

# Drop rows with missing age values
df_cleaned = df.dropna(subset=['Age'])

# Create age groups
bins = [0, 18, 30, 50, float('inf')]
labels = ['Children', 'Young Adults', 'Middle-Aged', 'Elderly']
df_cleaned['AgeGroup'] = pd.cut(df_cleaned['Age'], bins=bins, labels=labels, right=False)

# Group data by AgeGroup and Survival and calculate the counts
age_group_survival_count = df_cleaned.groupby(['AgeGroup', 'Survived']).size().unstack()

# Create the chart
plt.figure(figsize=(10, 6))
age_group_survival_count.plot(kind='bar', stacked=True, color=['r', 'g'])
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.title('Survival Count by Age Group')
plt.grid(True)
plt.legend(['Not Survived', 'Survived'])
plt.show()

# This data shows that each age group has similar survival rates.
# Out:
# /var/folders/w3/66ppzcd1609_hnn99kzt4dl40000gp/T/ipykernel_33512/1019636937.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['AgeGroup'] = pd.cut(df_cleaned['Age'], bins=bins, labels=labels, right=False)

# %% [markdown]
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# df = pd.read_csv('train.csv')
# df.drop(['Age','PassengerId','Name','Ticket','Cabin'], axis=1, inplace= True)
# df=pd.get_dummies(df,columns = ['Sex','Embarked'])
# X_train = df.drop('Survived', axis=1)
# y_train = df['Survived']
#
# logreg = LogisticRegression()
# logreg.fit(X_train, y_train)
#
# X_train
# y_train

# %%
X=X_train
y=y_train
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred=logreg.predict(X_test)
# Out:
# /Users/demetyildirim_1/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Accuracy: 0.78
# Precision: 0.76
# Recall: 0.73
# F1 Score: 0.75

# %%
# Count the number of different cabins
num_different_cabins = df['Cabin'].nunique()

print("Number of different cabins:", num_different_cabins)
# Out:
# Number of different cabins: 147

# %%
df[df['Age'].isnull()]
# Out:
#      Survived  Pclass  Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 5           0       3  NaN      0      0   8.4583           0         1
# 17          1       2  NaN      0      0  13.0000           0         1
# 19          1       3  NaN      0      0   7.2250           1         0
# 26          0       3  NaN      0      0   7.2250           0         1
# 28          1       3  NaN      0      0   7.8792           1         0
# ..        ...     ...  ...    ...    ...      ...         ...       ...
# 859         0       3  NaN      0      0   7.2292           0         1
# 863         0       3  NaN      8      2  69.5500           1         0
# 868         0       3  NaN      0      0   9.5000           0         1
# 878         0       3  NaN      0      0   7.8958           0         1
# 888         0       3  NaN      1      2  23.4500           1         0
#
#      Embarked_C  Embarked_Q  Embarked_S
# 5             0           1           0
# ...

# %%
logreg
# Access model parameters
coefficients = logreg.coef_
intercept = logreg.intercept_
n_iterations = logreg.n_iter_

print("Coefficients:", coefficients)
print("Intercept:", intercept)
print("Number of Iterations:", n_iterations)
# Out:
# Coefficients: [[-0.79754594 -0.23755459 -0.06896131  0.00293429  1.78357631 -0.90040216
#    0.49080669  0.30421752  0.02830898]]
# Intercept: [1.08169023]
# Number of Iterations: [100]

# %%
# Function to get input from the user and predict the status
def predict_status():
    Pclass = int(input("Enter passenger class (1, 2, or 3): "))
    Sex = input("Enter passenger gender (male or female): ")
    SibSp = int(input("Enter SibSp"))
    Parch = int(input("Enter Parch"))
    Fare = float(input("Enter passenger fare: "))
    Embarked = input("Enter embark status (C,Q,S)")
    
    
    # Preprocess the input data
    input_data = pd.DataFrame({
        'Pclass': [Pclass],
        'Sex': [Sex],
        'SibSp':[SibSp],
        'Parch':[Parch],
        'Fare': [Fare],
        'Embarked':[Embarked]
    })
    
    # Encode categorical features
    input_data = pd.get_dummies(input_data, columns=['Sex','Embarked'])
    
    # Make the prediction
    prediction = logreg.predict(input_data)[0]
    
    if prediction == 0:
        print("Not Survived")
    else:
        print("Survived")
    
predict_status()
# Out:
# Enter passenger class (1, 2, or 3): 1
# Enter passenger gender (male or female): male
# Enter SibSp0
# Enter Parch0
# Enter passenger fare: 8.1583
# Enter embark status (C,Q,S)C
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 32
#      29     else:
#      30         print("Survived")
# ---> 32 predict_status()
#
# Cell In[57], line 25, in predict_status()
#      22 input_data = pd.get_dummies(input_data, columns=['Sex','Embarked'])
#      24 # Make the prediction
# ---> 25 prediction = logreg.predict(input_data)[0]
#      27 if prediction == 0:
#      28     print("Not Survived")
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_base.py:419, in LinearClassifierMixin.predict(self, X)
#     405 """
#     406 Predict class labels for samples in X.
#     407
#    (...)
#     416     Vector containing the class labels for each sample.
# ...

# %%
X_train
# Out:
#      Pclass  SibSp  Parch     Fare  Sex_female  Sex_male  Embarked_C  \
# 517       3      0      0  24.1500           0         1           0
# 67        3      0      0   8.1583           0         1           0
# 437       2      2      3  18.7500           1         0           0
# 705       2      0      0  26.0000           0         1           0
# 834       3      0      0   8.3000           0         1           0
# ..      ...    ...    ...      ...         ...       ...         ...
# 335       3      0      0   7.8958           0         1           0
# 507       1      0      0  26.5500           0         1           0
# 59        3      5      2  46.9000           0         1           0
# 200       3      0      0   9.5000           0         1           0
# 433       3      0      0   7.1250           0         1           0
#
#      Embarked_Q  Embarked_S
# 517           1           0
# 67            0           1
# 437           0           1
# ...
